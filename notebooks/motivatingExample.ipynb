# %%
import numpy as np
import matplotlib.pyplot as plt

from robustDA import plots, plots_small

# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
data = plots_small.plot_motiv_example()
