# %%
import numpy as np
import matplotlib.pyplot as plt

from robustDA import plots

# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
data = plots.plot_motiv_example()

# %%
a = np.ceil(0.5*13)
b = np.ceil(0.5*15)
print(a)
print(b)
# Out:
# 7.0
# 8.0
